# %%
from loading_utils import load_matrix_from_csv
from network import create_graph_from_matrices
from visualize import visualize_network
import numpy as np
import nash_equilibrium as ne
from social_optimum import social_optimum, Latency
from visualize_flow import visualize_flow
from NE_continous import calculate_nash_flow as calculate_nash_flow_continous
from NE_discrete import calculate_nash_flow as calculate_nash_flow_discrete

# %% [markdown]
# ### Network 1

# %%
network_num = 1
path = '../data/network' + str(network_num) + '/'
# Load the matrices back from the CSV files
loaded_a_matrix = load_matrix_from_csv(path + 'a_matrix.csv')
loaded_b_matrix = load_matrix_from_csv(path + 'b_matrix.csv')
loaded_c_matrix = load_matrix_from_csv(path + 'c_matrix.csv')
n = len(loaded_a_matrix)
G_modified = create_graph_from_matrices(loaded_a_matrix, loaded_b_matrix, loaded_c_matrix)
visualize_network(G_modified)

# %%
G, partition, paths, final_latencies = calculate_nash_flow_continous(G_modified, 0, 2)
# Out:
# Stopping condition reached after  0  iterations!
# Final latencies:  [8.0]
# Final partition:  [1.0]

# %% [markdown]
# ### Network 2

# %%
network_num = 2
path = '../data/network' + str(network_num) + '/'
# Load the matrices back from the CSV files
loaded_a_matrix = load_matrix_from_csv(path + 'a_matrix.csv')
loaded_b_matrix = load_matrix_from_csv(path + 'b_matrix.csv')
loaded_c_matrix = load_matrix_from_csv(path + 'c_matrix.csv')
n = len(loaded_a_matrix)
G_modified = create_graph_from_matrices( loaded_a_matrix, loaded_b_matrix, loaded_c_matrix)
visualize_network(G_modified)

# %%
G, partition, paths, final_latencies = calculate_nash_flow_continous(G_modified, 0, 2)
# Out:
# Stopping condition reached after  9710  iterations!
# Final latencies:  [3.0082667247490757, 3.0082667198190003]
# Final partition:  [0.26556443768613747, 0.7344355623138613]

# %% [markdown]
# ### Network 3

# %%
network_num = 3
path = '../data/network' + str(network_num) + '/'
# Load the matrices back from the CSV files
loaded_a_matrix = load_matrix_from_csv(path + 'a_matrix.csv')
loaded_b_matrix = load_matrix_from_csv(path + 'b_matrix.csv')
loaded_c_matrix = load_matrix_from_csv(path + 'c_matrix.csv')
n = len(loaded_a_matrix)
G_modified = create_graph_from_matrices( loaded_a_matrix, loaded_b_matrix, loaded_c_matrix)
visualize_network(G_modified)

# %%
G, partition, paths, final_latencies = calculate_nash_flow_continous(G_modified, 0, 2)
# Out:
# Stopping condition reached after  8049  iterations!
# Final latencies:  [2.459340778624651, 2.459340764701346]
# Final partition:  [0.1925824061527448, 0.8074175938472551]

# %% [markdown]
# ### Network 4

# %%
network_num = 4
path = '../data/network' + str(network_num) + '/'
# Load the matrices back from the CSV files
loaded_a_matrix = load_matrix_from_csv(path + 'a_matrix.csv')
loaded_b_matrix = load_matrix_from_csv(path + 'b_matrix.csv')
loaded_c_matrix = load_matrix_from_csv(path + 'c_matrix.csv')
n = len(loaded_a_matrix)
G_modified = create_graph_from_matrices(loaded_a_matrix, loaded_b_matrix, loaded_c_matrix)
visualize_network(G_modified)

# %%
G, partition, paths, final_latencies = calculate_nash_flow_continous(G_modified, 0, 2)
# Out:
# Stopping condition reached after  8049  iterations!
# Final latencies:  [2.459340778624651, 2.459340764701346]
# Final partition:  [0.1925824061527448, 0.8074175938472551]

# %% [markdown]
# ### Network 5

# %%
network_num = 5
path = '../data/network' + str(network_num) + '/'
# Load the matrices back from the CSV files
loaded_a_matrix = load_matrix_from_csv(path + 'a_matrix.csv')
loaded_b_matrix = load_matrix_from_csv(path + 'b_matrix.csv')
loaded_c_matrix = load_matrix_from_csv(path + 'c_matrix.csv')
n = len(loaded_a_matrix)
G = create_graph_from_matrices( loaded_a_matrix, loaded_b_matrix, loaded_c_matrix)
visualize_network(G)

# %%
G, partition, paths, final_latencies = calculate_nash_flow_continous(G_modified, 0, 2)
# Out:
# Stopping condition reached after  8049  iterations!
# Final latencies:  [2.459340778624651, 2.459340764701346]
# Final partition:  [0.1925824061527448, 0.8074175938472551]
